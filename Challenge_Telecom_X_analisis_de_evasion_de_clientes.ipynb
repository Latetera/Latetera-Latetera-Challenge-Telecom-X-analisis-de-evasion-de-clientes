# %% [markdown]
# <a href="https://colab.research.google.com/github/Latetera/Latetera-Latetera-Challenge-Telecom-X-analisis-de-evasion-de-clientes/blob/main/Challenge_Telecom_X_analisis_de_evasion_de_clientes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **1. Extracción**

# %%
#importa Pandas
import pandas as pd

#cargar los datos desde la API e inspeccionar el dataframe
df = pd.read_json('TelecomX_Data.json')
df
# Out:
#       customerID Churn                                           customer  \
# 0     0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1     0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2     0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3     0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4     0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# ...          ...   ...                                                ...
# 7262  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265  9993-LHIEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266  9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# ...

# %% [markdown]
# ### **Normaliza los datos**

# %%
#enlista las columnas del dataframe original
columnas = df.columns
columnas
# Out:
# Index(['customerID', 'Churn', 'customer', 'phone', 'internet', 'account'], dtype='object')

# %%
#enlista las columnas que contienen datos anidados
columnas_anidadas = df.columns[2:]
columnas_anidadas
# Out:
# Index(['customer', 'phone', 'internet', 'account'], dtype='object')

# %%
#extraer los datos de todas las columnas anidadas
for col in columnas_anidadas:
    df_desglosado = pd.json_normalize(df[col])
    df = pd.concat([df.drop(col, axis=1), df_desglosado], axis=1)

# %%
#verificar el dataframe desglosado
df.sample(5)
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 4925  6728-VOIFY    No  Female              0     Yes         No      63
# 5403  7394-FKDNK   Yes  Female              0     Yes         No       9
# 2014  2845-AFFTX   Yes    Male              1     Yes         No      41
# 6861  9470-YFUYI    No    Male              1     Yes         No      71
# 6300  8663-UPDGF    No  Female              0      No         No      26
#
#      PhoneService MultipleLines InternetService  ... OnlineBackup  \
# 4925          Yes            No     Fiber optic  ...          Yes
# 5403          Yes            No     Fiber optic  ...           No
# 2014          Yes           Yes     Fiber optic  ...           No
# 6861          Yes            No             DSL  ...          Yes
# 6300          Yes           Yes             DSL  ...          Yes
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
#establecer como índice el ID de cliente
#df.set_index('customerID', inplace=True)

# %%
df
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     0002-ORFBO    No  Female              0     Yes        Yes       9
# 1     0003-MKNFE    No    Male              0      No         No       9
# 2     0004-TLHLJ   Yes    Male              0      No         No       4
# 3     0011-IGKFF   Yes    Male              1     Yes         No      13
# 4     0013-EXCHZ   Yes  Female              1     Yes         No       3
# ...          ...   ...     ...            ...     ...        ...     ...
# 7262  9987-LUTYD    No  Female              0      No         No      13
# 7263  9992-RRAMN   Yes    Male              0     Yes         No      22
# 7264  9992-UJOEL    No    Male              0      No         No       2
# 7265  9993-LHIEB    No    Male              0     Yes        Yes      67
# 7266  9995-HOTOH    No    Male              0     Yes        Yes      63
#
#      PhoneService     MultipleLines InternetService  ... OnlineBackup  \
# ...
